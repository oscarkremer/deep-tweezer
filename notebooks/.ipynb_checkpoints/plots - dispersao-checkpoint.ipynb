# %%
import pandas as pd
dataframe = pd.read_excel('dataset.xlsx', index=None)

# %%
dataframe.head(5)
dataframe.columns
# Out:
# Index(['Patient ID', 'Patient age quantile', 'SARS-Cov-2 exam result',
#        'Patient addmited to regular ward (1=yes, 0=no)',
#        'Patient addmited to semi-intensive unit (1=yes, 0=no)',
#        'Patient addmited to intensive care unit (1=yes, 0=no)', 'Hematocrit',
#        'Hemoglobin', 'Platelets', 'Mean platelet volume ',
#        ...
#        'Hb saturation (arterial blood gases)',
#        'pCO2 (arterial blood gas analysis)',
#        'Base excess (arterial blood gas analysis)',
#        'pH (arterial blood gas analysis)',
#        'Total CO2 (arterial blood gas analysis)',
#        'HCO3 (arterial blood gas analysis)',
#        'pO2 (arterial blood gas analysis)', 'Arteiral Fio2', 'Phosphor',
#        'ctO2 (arterial blood gas analysis)'],
#       dtype='object', length=111)

# %%
dataframe = dataframe[['Patient ID', 'SARS-Cov-2 exam result', 'Hematocrit',
       'Hemoglobin', 'Platelets', 'Mean platelet volume ', 'Red blood Cells',
       'Lymphocytes',
       'Leukocytes', 'Basophils', 'Mean corpuscular hemoglobin (MCH)',
       'Eosinophils', 'Mean corpuscular volume (MCV)', 'Monocytes',
       'Red blood cell distribution width (RDW)']]
for column in dataframe.columns:
    print(dataframe[column])
    print(column)
# Out:
# 0       44477f75e8169d2
# 1       126e9dd13932f68
# 2       a46b4402a0e5696
# 3       f7d619a94f97c45
# 4       d9e41465789c2b5
# 5       75f16746216c4d1
# 6       2a2245e360808d7
# 7       509197ec73f1400
# 8       8bb9d64f0215244
# 9       5f1ed301375586c
# 10      d720464cc322b6f
# 11      02c84e61d5f9e18
# 12      b68a6f32fd88a49
# 13      0fbafd910aa8078
# 14      f9056545d1296ec
# 15      6c9d3323975b082
# 16      b62e45a8a3f683e
# 17      99da3c055438133
# 18      d3ea751f3db9de9
# 19      315cc65959223e0
# 20      fe656baa2bfc5dd
# 21      93b8a7ad37b1400
# 22      2c2eae16c12a18a
# 23      59b54b15e19da77
# 24      d153a96599e2d41
# 25      6b43d02183a4e72
# 26      fe26809ebb6ef44
# 27      50abe42feb0b703
# 28      fc41531ca4faf1e
# 29      891d0f6449ff3d7
#              ...
# 5614    88cce1444e16f9c
# 5615    2733fac0d3f7138
# 5616    c77364a15718286
# 5617    b34211b6f18c0cc
# 5618    acd761fe16b5d0f
# 5619    d85d594eca6cbb1
# 5620    f60118eba52d74a
# ...

# %%
dataframe = dataframe.fillna(0)
print(dataframe.head())
for index, rows in dataframe.iterrows():
    columns = ['Hematocrit',
       'Hemoglobin', 'Platelets', 'Mean platelet volume ', 'Red blood Cells',
       'Lymphocytes',
       'Leukocytes', 'Basophils', 'Mean corpuscular hemoglobin (MCH)',
       'Eosinophils', 'Mean corpuscular volume (MCV)', 'Monocytes',
       'Red blood cell distribution width (RDW)']
    iterator=0
    for column in columns:
        print(rows[column])
        if rows[column] == 0:
            iterator+=1
    print(iterator)
    if iterator==len(columns):
        dataframe = dataframe.drop(index)
# Out:
#         Patient ID SARS-Cov-2 exam result  Hematocrit  Hemoglobin  Platelets  \
# 0  44477f75e8169d2               negative    0.000000     0.00000   0.000000
# 1  126e9dd13932f68               negative    0.236515    -0.02234  -0.517413
# 2  a46b4402a0e5696               negative    0.000000     0.00000   0.000000
# 3  f7d619a94f97c45               negative    0.000000     0.00000   0.000000
# 4  d9e41465789c2b5               negative    0.000000     0.00000   0.000000
#
#    Mean platelet volume   Red blood Cells  Lymphocytes  Leukocytes  Basophils  \
# 0               0.000000         0.000000     0.000000     0.00000   0.000000
# 1               0.010677         0.102004     0.318366    -0.09461  -0.223767
# 2               0.000000         0.000000     0.000000     0.00000   0.000000
# 3               0.000000         0.000000     0.000000     0.00000   0.000000
# 4               0.000000         0.000000     0.000000     0.00000   0.000000
#
# ...

# %%
dataframe
# Out:
#            Patient ID SARS-Cov-2 exam result  Hematocrit  Hemoglobin  \
# 1     126e9dd13932f68               negative    0.236515   -0.022340
# 8     8bb9d64f0215244               negative   -1.571682   -0.774212
# 15    6c9d3323975b082               negative   -0.747693   -0.586244
# 18    d3ea751f3db9de9               negative    0.991838    0.792188
# 22    2c2eae16c12a18a               negative    0.190738   -0.147652
# 28    fc41531ca4faf1e               negative    1.014726    0.854844
# 29    891d0f6449ff3d7               negative    0.740064    0.854844
# 30    ebdd7c67fcb21b4               negative   -0.679027   -0.711556
# 32    296adf066a9bf03               negative    0.236515    0.040316
# 34    0b1e43c5e3fb1d1               negative    0.808730    1.042812
# 36    c0aa8a22eaccb63               negative   -0.106813   -0.335620
# 38    826f654dbf80245               negative    1.426721    1.230779
# 40    a2432a45830c32d               negative    0.717175    0.604220
# ...

# %%
positives = 0
for value in dataframe['SARS-Cov-2 exam result'].values:
    if value == 'positive':
        positives+=1
positives
# Out:
# 83

# %%
import seaborn as sns
sns.pairplot(dataframe, hue="SARS-Cov-2 exam result")

# %%
dataframe.head()
# Out:
#          Patient ID SARS-Cov-2 exam result  Hematocrit  Hemoglobin  Platelets  \
# 1   126e9dd13932f68               negative    0.236515   -0.022340  -0.517413
# 8   8bb9d64f0215244               negative   -1.571682   -0.774212   1.429667
# 15  6c9d3323975b082               negative   -0.747693   -0.586244  -0.429480
# 18  d3ea751f3db9de9               negative    0.991838    0.792188   0.072992
# 22  2c2eae16c12a18a               negative    0.190738   -0.147652  -0.668155
#
#     Mean platelet volume   Red blood Cells  Lymphocytes  Leukocytes  \
# 1                0.010677         0.102004     0.318366   -0.094610
# 8               -1.672222        -0.850035    -0.005738    0.364550
# 15              -0.213711        -1.361315    -1.114514   -0.884923
# 18              -0.550290         0.542763     0.045436   -0.211488
# 22               1.020415        -0.127191     0.002791   -1.132592
#
#     Basophils  Mean corpuscular hemoglobin (MCH)  Eosinophils  \
# ...

# %%
sns.pairplot(dataframe[['SARS-Cov-2 exam result', 'Platelets', 'Leukocytes', 'Eosinophils', 'Monocytes']], hue="SARS-Cov-2 exam result")

# %%
len(dataframe[['SARS-Cov-2 exam result']].values)
# Out:
# 603
