# %%
from os import path
from src.environment import Tweezer, Pendulum
import numpy as np
import matplotlib.pyplot as plt
from time import time
from tqdm import tqdm
from scipy import signal
from scipy.stats.kde import gaussian_kde
rng = np.random.default_rng()
# Out:
# /home/oscar.kremer/miniconda3/envs/deep-tweezer/lib/python3.6/site-packages/gym/core.py:26: UserWarning: WARN: Gym minimally supports python 3.6 as the python foundation not longer supports the version, please update your version to 3.7+
#   "Gym minimally supports python 3.6 as the python foundation not longer supports the version, please update your version to 3.7+"

# %%
def get_states(env, time_steps=10**6):
    s = env.reset()
    states = []
    for i in tqdm(range(time_steps)):
        sP, r, done, a, _ = env.step(np.array([0]))
        states.append(sP.reshape(-1))
    return np.array(states)

# %%
pressures = [10**3, 10**1, 10**-1]
states = {'{}mbar'.format(pressure/100) : get_states(Tweezer(pressure=pressure)) for pressure in pressures}
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]/home/oscar.kremer/deep-tweezer/src/environment/tweezer.py:95: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   yddot_i_plus])
# ...
# 100%|██████████| 1000000/1000000 [01:05<00:00, 15249.11it/s]

# %%
psds = {pressure : signal.welch(states[pressure][:,0], fs=1/Tweezer().dt, nperseg=10**6)  for pressure in states.keys()}
plt.figure(figsize=(15, 4))
norm_factor = 10**24 ##factor added to have same unit in the plot as the Quidant Paper
for key in psds.keys():
    plt.semilogy(psds[key][0], norm_factor*psds[key][1], label=key)
plt.title('PSD: power spectral density')
plt.xlim(100*10**3, 200*10**3)
plt.ylim(10**-8, 2*10**11)
plt.xlabel('Frequency')
plt.ylabel('Power (pm²}/Hz)')
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
